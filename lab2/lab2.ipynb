# %%
import cv2
import numpy as np

# %%
image=cv2.imread('/home/cvl-5aiml-a2/Downloads/stars.jpg',0)
image=image.astype(np.float32)

c=255/(np.log(1+np.max(image)))
#c=55
log_transformed=c * np.log(1+image)

log_transformed=np.array(log_transformed,dtype=np.uint8)


cv2.imshow("Stars original ",image)

cv2.imshow("Stars Log-tranformed ",log_transformed)

while True:

   if(cv2.waitKey(0) & 0xFF == ord('q')):
      break
#cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np


img = cv2.imread('/home/cvl-5aiml-a2/Downloads/stars.jpg')

# Trying 4 gamma values
for gamma in [0.1, 0.5, 1.2, 2.2]:
    # Apply gamma correction
    gamma_corrected = np.array(255 * (img / 255) ** gamma, dtype='uint8')

    
    cv2.imwrite('gamma_transformed_e' + str(gamma) + '.jpg', gamma_corrected)

# %%
import cv2
import numpy as np

# Function to map each intensity level to output intensity level.
def pixelVal(pix, r1, s1, r2, s2):
    if (0 <= pix and pix <= r1):
        return (s1 / r1) * pix
    elif (r1 < pix and pix <= r2):
        return ((s2 - s1) / (r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2) / (255 - r2)) * (pix - r2) + s2

# Open the image.
img = cv2.imread('/home/cvl-5aiml-a2/Downloads/stars.jpg')

# Define parameters.
r1 = 70
s1 = 0
r2 = 140
s2 = 255

# Vectorize the function to apply it to each value in the NumPy array.
pixelVal_vec = np.vectorize(pixelVal)

# Apply contrast stretching.
contrast_stretched = pixelVal_vec(img, r1, s1, r2, s2)

# Save edited image.
cv2.imwrite('contrast_stretch.jpg', contrast_stretched)
# Out:
# [ WARN:0@378.524] global loadsave.cpp:1063 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# True

# %%
image=cv2.imread('/home/cvl-5aiml-a2/Downloads/bugatti.jpg',cv2.IMREAD_GRAYSCALE)
#image=image.astype(np.float32)

negative=255-image
cv2.imshow("Original",image)

cv2.imshow("Inverted negative",negative)
while True:

   if(cv2.waitKey(0) & 0xFF == ord('q')):
      break
cv2.destroyAllWindows()

# %%
    
import matplotlib.pyplot as plt
image=cv2.imread('/home/cvl-5aiml-a2/Downloads/bugatti.jpg',cv2.IMREAD_GRAYSCALE)

equ=cv2.equalizeHist(image)
cv2.imshow("Original",image)

cv2.imshow("Equalized",equ)

# image
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title("Original Image Histogram")
plt.hist(image.ravel(), 256, [0,256])
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

# equalized image
plt.subplot(1,2,2)
plt.title("Equalized Image Histogram")
plt.hist(equ.ravel(), 256, [0,256])
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

cv2.imshow("Original",image)

cv2.imshow("Eqaulized",equ)
while True:

   if(cv2.waitKey(0) & 0xFF == ord('q')):
      break
cv2.destroyAllWindows()
# Out:
# /tmp/ipykernel_359491/2349639064.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(image.ravel(), 256, [0,256])
# /tmp/ipykernel_359491/2349639064.py:20: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equ.ravel(), 256, [0,256])

# %%
from skimage import exposure, io, img_as_ubyte
import cv2

# Load images in grayscale (or color)
source = cv2.imread('source.jpg', cv2.IMREAD_GRAYSCALE)
reference = cv2.imread('reference.jpg', cv2.IMREAD_GRAYSCALE)

# Perform histogram specification
matched = exposure.match_histograms(source, reference, channel_axis=None)

# Convert to uint8 if needed
matched = img_as_ubyte(matched)

# Display results
cv2.imshow("Source", source)
cv2.imshow("Reference", reference)
cv2.imshow("Matched", matched)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [ WARN:0@478.885] global loadsave.cpp:275 findDecoder imread_('source.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@478.885] global loadsave.cpp:275 findDecoder imread_('reference.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       6 reference = cv2.imread('reference.jpg', cv2.IMREAD_GRAYSCALE)
#       8 # Perform histogram specification
# ----> 9 matched = exposure.match_histograms(source, reference, channel_axis=None)
#      11 # Convert to uint8 if needed
#      12 matched = img_as_ubyte(matched)
#
# File ~/cvenv/lib/python3.11/site-packages/skimage/_shared/utils.py:445, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     442 channel_axis = kwargs.get('channel_axis', None)
#     444 if channel_axis is None:
# --> 445     return func(*args, **kwargs)
# ...

# %%
image = cv2.imread('/home/cvl-5aiml-a2/Downloads/bugatti.jpg',0)
cv2.imshow('Original Image', image)
 
down_width = 300
down_height = 200
down_points = (down_width, down_height)
resized_down = cv2.resize(image, down_points, interpolation= cv2.INTER_LINEAR)
 
up_width = 600
up_height = 400
up_points = (up_width, up_height)
resized_up = cv2.resize(image, up_points, interpolation= cv2.INTER_LINEAR)
 

cv2.imshow('Resized Down by defining height and width', resized_down)
cv2.waitKey()
cv2.imshow('Resized Up image by defining height and width', resized_up)
cv2.waitKey()
 
cv2.destroyAllWindows()

# %%
img = cv2.imread('/home/cvl-5aiml-a2/Downloads/bugatti.jpg')
cropped = img[100:300, 200:400]  # From row 100 to 300, and column 200 to 400

cv2.imshow("Original",img)
cv2.waitKey()
cv2.imshow("Cropped Image", cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()
